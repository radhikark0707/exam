# %%
import pandas as pd

# %%
data=pd.read_csv('/content/ny-flights.csv')
data
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
# ...                    ...            ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
data.head()
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %%
data.tail()
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 20812  2014-01-31 00:00:00             UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00             UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00             UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00             UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00             MQ       20398   N609MQ    3699    BUF
#
#       dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 20812  ORD     801.0       -4.0     908.0        4.0        0.0
# 20813  CLE    1522.0      -10.0    1649.0      -31.0        0.0
# 20814  IAH     719.0       -6.0    1006.0      -20.0        0.0
# 20815  IAH     852.0        7.0    1156.0       -6.0        0.0
# 20816  ORD    1208.0      -12.0    1251.0      -19.0        0.0
#
#                        arr                  dep
# 20812  2014-01-31 09:08:00  2014-01-31 08:01:00
# ...

# %%
data.shape
# Out:
# (20817, 14)

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 291438

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20817 entries, 0 to 20816
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   fl_date         20817 non-null  object
#  1   unique_carrier  20817 non-null  object
#  2   airline_id      20817 non-null  int64
#  3   tail_num        20512 non-null  object
#  4   fl_num          20817 non-null  int64
#  5   origin          20817 non-null  object
#  6   dest            20817 non-null  object
#  7   dep_time        18462 non-null  float64
#  8   dep_delay       18462 non-null  float64
#  9   arr_time        18412 non-null  float64
#  10  arr_delay       18383 non-null  float64
#  11  cancelled       20817 non-null  float64
#  12  arr             18412 non-null  object
#  13  dep             18462 non-null  object
# dtypes: float64(5), int64(2), object(7)
# memory usage: 2.2+ MB

# %%
data.describe()
# Out:
#          airline_id        fl_num      dep_time     dep_delay      arr_time  \
# count  20817.000000  20817.000000  18462.000000  18462.000000  18412.000000
# mean   20109.614882   1826.098813   1319.991713     22.772127   1493.698566
# std      370.715209   1548.188325    479.999940     59.766152    518.851657
# min    19393.000000      1.000000      1.000000   -112.000000      1.000000
# 25%    19790.000000    472.000000    858.000000     -4.000000   1110.750000
# 50%    20355.000000   1457.000000   1336.000000      0.000000   1519.000000
# 75%    20409.000000   2701.000000   1720.000000     22.000000   1923.000000
# max    21171.000000   6258.000000   2400.000000    973.000000   2400.000000
#
#           arr_delay    cancelled
# count  18383.000000  20817.00000
# mean      21.380732      0.11505
# std       64.605591      0.31909
# min     -112.000000      0.00000
# 25%      -12.000000      0.00000
# 50%        3.000000      0.00000
# 75%       28.000000      0.00000
# ...

# %%
data.sample(2)
# Out:
#                    fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 8506   2014-01-13 00:00:00             EV       20366   N371CA    5366    HPN
# 12530  2014-01-19 00:00:00             MQ       20398   N826MQ    3530    LGA
#
#       dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 8506   ATL    1010.0       -3.0    1245.0        8.0        0.0
# 12530  DTW    1703.0       -7.0    1904.0       -6.0        0.0
#
#                        arr                  dep
# 8506   2014-01-13 12:45:00  2014-01-13 10:10:00
# 12530  2014-01-19 19:04:00  2014-01-19 17:03:00

# %%
map={'unique_carrier':'uniquecarrier'}
data=data.rename(columns=map)
data
# Out:
#                    fl_date uniquecarrier  airline_id tail_num  fl_num origin  \
# 0      2014-01-01 00:00:00            AA       19805   N338AA       1    JFK
# 1      2014-01-01 00:00:00            AA       19805   N335AA       3    JFK
# 2      2014-01-01 00:00:00            AA       19805   N327AA      21    JFK
# 3      2014-01-01 00:00:00            AA       19805   N3EHAA      29    LGA
# 4      2014-01-01 00:00:00            AA       19805   N319AA     117    JFK
# ...                    ...           ...         ...      ...     ...    ...
# 20812  2014-01-31 00:00:00            UA       19977   N54711    1253    ROC
# 20813  2014-01-31 00:00:00            UA       19977   N77525    1429    LGA
# 20814  2014-01-31 00:00:00            UA       19977   N37293    1456    LGA
# 20815  2014-01-31 00:00:00            UA       19977   N24729    1457    LGA
# 20816  2014-01-31 00:00:00            MQ       20398   N609MQ    3699    BUF
#
# ...

# %%
data['origin']
# Out:
# 0        JFK
# 1        JFK
# 2        JFK
# 3        LGA
# 4        JFK
#         ...
# 20812    ROC
# 20813    LGA
# 20814    LGA
# 20815    LGA
# 20816    BUF
# Name: origin, Length: 20817, dtype: object

# %%
data.dtypes
# Out:
# fl_date           object
# uniquecarrier     object
# airline_id         int64
# tail_num          object
# fl_num             int64
# origin            object
# dest              object
# dep_time         float64
# dep_delay        float64
# arr_time         float64
# arr_delay        float64
# cancelled        float64
# arr               object
# dep               object
# dtype: object

# %%
data['tail_num'].unique()
# Out:
# array(['N338AA', 'N335AA', 'N327AA', ..., 'N54711', 'N77525', 'N37293'],
#       dtype=object)

# %%
data['tail_num'].value_counts()
# Out:
# tail_num
# N292JB    76
# N258JB    69
# N306JB    68
# N523MQ    59
# N324JB    58
#           ..
# N77520     1
# N179UW     1
# N14143     1
# N124US     1
# N37293     1
# Name: count, Length: 2734, dtype: int64

# %%
data=data.sort_values('tail_num')
data
# Out:
#                    fl_date uniquecarrier  airline_id tail_num  fl_num origin  \
# 14689  2014-01-22 00:00:00            DL       19790   D942DN    2129    ROC
# 12516  2014-01-19 00:00:00            MQ       20398   N0EGMQ    3391    LGA
# 16527  2014-01-25 00:00:00            MQ       20398   N0EGMQ    3391    LGA
# 9972   2014-01-15 00:00:00            MQ       20398   N0EGMQ    3670    LGA
# 10320  2014-01-16 00:00:00            MQ       20398   N0EGMQ    3674    LGA
# ...                    ...           ...         ...      ...     ...    ...
# 18212  2014-01-28 00:00:00            UA       19977      NaN    1456    LGA
# 18241  2014-01-28 00:00:00            UA       19977      NaN     691    LGA
# 19240  2014-01-29 00:00:00            UA       19977      NaN     461    LGA
# 19269  2014-01-29 00:00:00            US       20355      NaN    2150    LGA
# 19280  2014-01-29 00:00:00            US       20355      NaN    2175    LGA
#
# ...

# %%
data.head(1)
# Out:
#                    fl_date uniquecarrier  airline_id tail_num  fl_num origin  \
# 14689  2014-01-22 00:00:00            DL       19790   D942DN    2129    ROC
#
#       dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 14689  ATL     600.0        0.0     834.0        3.0        0.0
#
#                        arr                  dep
# 14689  2014-01-22 08:34:00  2014-01-22 06:00:00

# %%
data.isnull()
# Out:
#        fl_date  uniquecarrier  airline_id  tail_num  fl_num  origin   dest  \
# 14689    False          False       False     False   False   False  False
# 12516    False          False       False     False   False   False  False
# 16527    False          False       False     False   False   False  False
# 9972     False          False       False     False   False   False  False
# 10320    False          False       False     False   False   False  False
# ...        ...            ...         ...       ...     ...     ...    ...
# 18212    False          False       False      True   False   False  False
# 18241    False          False       False      True   False   False  False
# 19240    False          False       False      True   False   False  False
# 19269    False          False       False      True   False   False  False
# 19280    False          False       False      True   False   False  False
#
# ...

# %%
data.head(1)
# Out:
#                    fl_date uniquecarrier  airline_id tail_num  fl_num origin  \
# 14689  2014-01-22 00:00:00            DL       19790   D942DN    2129    ROC
#
#       dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 14689  ATL     600.0        0.0     834.0        3.0        0.0
#
#                        arr                  dep
# 14689  2014-01-22 08:34:00  2014-01-22 06:00:00

# %%
data.dep_time.mean()
# Out:
# 1319.9917127071824

# %%
data.dep_delay.median()
# Out:
# 0.0

# %%
c=data.groupby('airline_id')
c['airline_id'].agg(['mean','median','count','min'])
# Out:
#                mean   median  count    min
# airline_id
# 19393       19393.0  19393.0   1917  19393
# 19690       19690.0  19690.0     29  19690
# 19790       19790.0  19790.0   3803  19790
# 19805       19805.0  19805.0   2427  19805
# 19977       19977.0  19977.0   1106  19977
# 20304       20304.0  20304.0     11  20304
# 20355       20355.0  20355.0   1568  20355
# 20366       20366.0  20366.0   2080  20366
# 20398       20398.0  20398.0   2434  20398
# 20409       20409.0  20409.0   4902  20409
# 20436       20436.0  20436.0     33  20436
# 20437       20437.0  20437.0    206  20437
# 21171       21171.0  21171.0    301  21171

# %%
data.dtypes
# Out:
# fl_date           object
# uniquecarrier     object
# airline_id         int64
# tail_num          object
# fl_num             int64
# origin            object
# dest              object
# dep_time         float64
# dep_delay        float64
# arr_time         float64
# arr_delay        float64
# cancelled        float64
# arr               object
# dep               object
# dtype: object
